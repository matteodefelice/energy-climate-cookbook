# %% [markdown]
# ### Modules used in this notebook
# `pypsa`, `plotnine`
# The notebook also requires a solver (e.g. `Cbc` or GLPK)

# %% [markdown]
# ## E.001: Creating your first power system model
# In this notebook you will create a simple power system model simulating a system with specific month of the year using wind and solar profiles based on atmospheric reanalysis data. The model will be optimised to define the optimal capacity of batteries needed to balance the system.
#
# The used model is PyPSA: [an open-source power system model](https://pypsa.org/)

# %% [markdown]
# # Step 02: Load wind, solar, demand data
# We use a set of Parquet files containing the electricity demand, wind and solar profiles based on [this dataset](https://researchdata.reading.ac.uk/272/) developed by Bloomfield et al., University of Reading.
#
# The Parquet files provide a data frame with the hourly values for all the European countries for the years 2000-2019 (the original dataset goes back to 1979 but we have kept only the last 20 years to reduce the amount of storage needed to run this notebook).

# %%
import pandas as pd
pd.options.future.infer_string = False #  Force pandas to use legacy string dtype (needed for pandas 3.0+)

dem = pd.read_parquet('../data/ERA5_full_demand_all_countries_2000_2019_hourly.parquet')
pv  = pd.read_parquet('../data/ERA5_solar_power_capacity_factor_all_countries_2000_2019_hourly.parquet')
win = pd.read_parquet('../data/ERA5_wind_power_capacity_factor_all_countries_2000_2019_inclusive.parquet')
dem.head()
# Out:
#                    datetime   Austria   Belgium  Bulgaria   Croatia  \
# 0 2000-01-01 00:00:00+00:00  6.149653  8.547436  4.288882  1.557109
# 1 2000-01-01 01:00:00+00:00  6.005393  8.184474  4.241575  1.474065
# 2 2000-01-01 02:00:00+00:00  5.854461  7.972377  4.265739  1.445917
# 3 2000-01-01 03:00:00+00:00  5.945950  7.954598  4.407904  1.465845
# 4 2000-01-01 04:00:00+00:00  6.444086  8.264821  4.780009  1.587208
#
#    Czech_Republic   Denmark    Finland     France    Germany  ...     Norway  \
# 0        6.583412  2.543370  10.218680  56.496736  40.287049  ...  15.602364
# 1        6.535270  2.489337  10.133998  55.007324  39.336272  ...  15.424182
# 2        6.463566  2.492441  10.185449  52.251049  39.381310  ...  15.410204
# 3        6.551649  2.553254  10.472526  51.265385  40.223583  ...  15.522155
# 4        6.891379  2.748628  11.128114  53.134412  42.170035  ...  15.911743
#
#       Poland  Portugal   Romania  Slovakia  Slovenia      Spain     Sweden  \
# 0  15.173096  5.161892  6.074548  3.032983  1.177564  23.342019  16.258756
# 1  14.849854  4.776771  6.029861  2.986461  1.152904  22.036881  16.147893
# 2  14.818497  4.538195  6.085059  2.987110  1.149503  21.423310  16.162053
# 3  15.023909  4.418843  6.265306  3.048357  1.170514  21.222722  16.324404
# 4  15.634865  4.369596  6.687905  3.175566  1.260816  21.653859  16.956360
#
#    Switzerland  United_Kingdom
# 0     6.420162       31.481235
# 1     6.465112       29.741144
# 2     6.489145       27.999955
# 3     6.523057       27.066848
# 4     6.423579       26.070716
#
# [5 rows x 29 columns]

# %% [markdown]
# # Step 03: selecting year, month, and country
# In this example we simulate a power system model consisting of a wind power farm, a solar plant and a lithium-ion battery using the electricity demand and the RES profiles (capacity factors) for a specific country and a specific month.

# %%
selected_year = 2012 # 2000-2019
selected_month = 2 # 1 = January, 12 = December
country = 'Netherlands'

# %%
# Select demand, solar (PV) and wind profiles
selected_dem = dem.loc[(pd.DatetimeIndex(dem['datetime']).year == selected_year) & (pd.DatetimeIndex(dem['datetime']).month == selected_month)][country]
selected_pv  = pv.loc[(pd.DatetimeIndex(pv['datetime']).year == selected_year) & (pd.DatetimeIndex(pv['datetime']).month == selected_month)][country]
selected_win = win.loc[(pd.DatetimeIndex(win['datetime']).year == selected_year) & (pd.DatetimeIndex(win['datetime']).month == selected_month)][country]

# %%
selected_pv.loc[selected_pv < 0] = 0

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 4))
plt.plot(selected_pv)
plt.plot(selected_win)
plt.show()

# %% [markdown]
# # Step 04: Building the power system model
#
# We create here a single-bus PyPSA network with:
#   - `Wind`: A wind generator with the cost of 35 000 EUR per MW
#   - `Solar`: a solar generator with the cost of 20 000 EUR per MW
#   - `Battery`: a battery with 3 hours of storage with the cost of 45 000 EUR per MW. The efficiency is 90%.
#
# The system has an electricity demand defined by the load `L1`

# %%
import pypsa

network = pypsa.Network(snapshots = selected_dem.index)
network.add("Bus", "B1")

network.add("Generator", "Wind",
            bus="B1",
            capital_cost = 35_000,
            p_max_pu = selected_win,
            p_nom_extendable = True,
            control="PQ")

network.add("Generator", "Solar",
            bus="B1",
            capital_cost = 20_000,
            p_max_pu = selected_pv,
            p_nom_extendable = True,
            control="PQ")

network.add("StorageUnit", "Battery",
            bus="B1",
            capital_cost = 45_000,
            marginal_cost = 0.01,
            efficiency_store = 0.9,
            efficiency_dispatch = 0.9,
            max_hours = 3,
            p_nom_extendable = True
            )

network.add("Load", "L1",
            bus="B1",
            p_set=selected_dem*1e3)

# %% [markdown]
# # Step 05: Running the model
# Here we solve the linear optimal power flow defined in the PyPSA network created in the step before. We print the optimal capacities (in MW) of wind, solar and batteries found by the solver.

# %%
network.optimize()
# Out:
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['B1'], dtype='str', name='name')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 network.optimize()
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\pypsa\optimization\optimize.py:466, in OptimizationAccessor.__call__(self, snapshots, multi_investment_periods, transmission_losses, linearized_unit_commitment, model_kwargs, extra_functionality, assign_all_duals, solver_name, solver_options, compute_infeasibilities, **kwargs)
#     463 n._linearized_uc = linearized_unit_commitment
#     465 n.consistency_check(strict=["unknown_buses"])
# --> 466 m = n.optimize.create_model(
#     467     sns,
#     468     multi_investment_periods,
#     469     transmission_losses,
#     470     linearized_unit_commitment,
#     471     consistency_check=False,
#     472     **model_kwargs,
#     473 )
#     474 if extra_functionality:
#     475     extra_functionality(n, sns)
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\pypsa\optimization\optimize.py:598, in OptimizationAccessor.create_model(self, snapshots, multi_investment_periods, transmission_losses, linearized_unit_commitment, consistency_check, **kwargs)
#     590     define_nodal_balance_constraints(
#     591         n,
#     592         sns,
#    (...)
#     595         suffix="-meshed",
#     596     )
#     597 else:
# --> 598     define_nodal_balance_constraints(
#     599         n, sns, transmission_losses=transmission_losses
#     600     )
#     602 define_kirchhoff_voltage_constraints(n, sns)
#     603 define_storage_unit_constraints(n, sns)
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\pypsa\optimization\constraints.py:935, in define_nodal_balance_constraints(n, sns, transmission_losses, buses, suffix)
#     932 expr = sign * m[f"{c.name}-{attr}"]
#     934 cbuses = c._as_xarray(column)
# --> 935 cbuses = cbuses.sel(name=c.active_assets)
#     936 # Only keep the first scenario if there are multiple
#     937 if n.has_scenarios:
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\xarray\core\dataarray.py:1717, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1601 def sel(
#    1602     self,
#    1603     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1607     **indexers_kwargs: Any,
#    1608 ) -> Self:
#    1609     """Return a new DataArray whose data is given by selecting index
#    1610     labels along the specified dimension(s).
#    1611
#    (...)
#    1715     Dimensions without coordinates: points
#    1716     """
# -> 1717     ds = self._to_temp_dataset().sel(
#    1718         indexers=indexers,
#    1719         drop=drop,
#    1720         method=method,
#    1721         tolerance=tolerance,
#    1722         **indexers_kwargs,
#    1723     )
#    1724     return self._from_temp_dataset(ds)
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\xarray\core\dataset.py:3014, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    3011             query_results.drop_coords.append(k)
#    3012     query_results.variables = no_scalar_variables
# -> 3014 result = self.isel(indexers=query_results.dim_indexers, drop=drop)
#    3015 return result._overwrite_indexes(*query_results.as_tuple()[1:])
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\xarray\core\dataset.py:2867, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2865 var_indexers = {k: v for k, v in indexers.items() if k in var.dims}
#    2866 if var_indexers:
# -> 2867     var = var.isel(var_indexers)
#    2868     if drop and var.ndim == 0 and name in coord_names:
#    2869         coord_names.remove(name)
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\xarray\core\variable.py:1130, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1127 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1129 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1130 return self[key]
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\xarray\core\variable.py:818, in Variable.__getitem__(self, key)
#     805 """Return a new Variable object whose contents are consistent with
#     806 getting the provided key from the underlying data.
#     807
#    (...)
#     815 array `x.values` directly.
#     816 """
#     817 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 818 indexable = as_indexable(self._data)
#     820 data = indexing.apply_indexer(indexable, indexer)
#     822 if new_order:
#
# File c:\Users\matte\miniconda3\envs\cookbook\Lib\site-packages\xarray\core\indexing.py:1024, in as_indexable(array)
#    1021 if hasattr(array, "__array_function__"):
#    1022     return NdArrayLikeIndexingAdapter(array)
# -> 1024 raise TypeError(f"Invalid array type: {type(array)}")
#
# TypeError: Invalid array type: <class 'pandas.arrays.ArrowStringArray'>

# %%
network.statistics.expanded_capacity()
# Out:
# component    carrier
# Generator    -          194425.1
# StorageUnit  -           46887.9
# dtype: float64

# %% [markdown]
# # Step 06: Plotting the dispatching
# To plot the generation of the three assets modeled in this example we need to insert the data contained in the `network` object into a Pandas data frame. This is eventually used for a plot made with [plotnine](https://plotnine.readthedocs.io/en/stable/)

# %%
gen_list = network.generators[['bus']].reset_index()
gen_list['type'] = gen_list['Generator'].str.split('_', expand = True).iloc[:,0]
gen = (pd.merge(
    network.generators_t.p
    .unstack()
    .reset_index(), gen_list)
       .groupby(['type', 'bus', 'snapshot'])
       .sum()
       .reset_index()
      ).rename(columns = {0: 'prod'})

sto_list = network.storage_units[['bus']].reset_index()
sto_list['type'] = sto_list['StorageUnit'].str.split('_', expand = True).iloc[:,0]
sto = (pd.merge(
    network.storage_units_t.p
    .unstack()
    .reset_index(), sto_list)
       .groupby(['type', 'bus', 'snapshot'])
       .sum().reset_index()
      ).rename(columns = {0: 'prod'})

df = pd.concat([gen, sto])
df.head()
# Out:
#     type bus  snapshot Generator  prod StorageUnit
# 0  Solar  B1    105936     Solar   0.0         NaN
# 1  Solar  B1    105937     Solar   0.0         NaN
# 2  Solar  B1    105938     Solar   0.0         NaN
# 3  Solar  B1    105939     Solar   0.0         NaN
# 4  Solar  B1    105940     Solar   0.0         NaN

# %%
import plotnine
plotnine.options.figure_size = (12, 4)

(
    plotnine.ggplot(pd.DataFrame(network.loads_t.p_set.L1).reset_index(), plotnine.aes(x='snapshot', y='L1')) +
    plotnine.geom_area(plotnine.aes(x = 'snapshot', y = 'prod', fill = 'type'), data= df) +
    plotnine.geom_line() +
    plotnine.theme_bw()
)
# Out:
# INFO:matplotlib.font_manager:Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
plt.plot(network.storage_units_t.state_of_charge)
plt.show()
